# %%
# !pip install tensorflow==2.14.0 tensorflow-gpu
# Out:
# Collecting tensorflow==2.14.0
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !git clone https://github.com/ealeongomez/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features.git
# Out:
# Cloning into 'Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 55 (delta 10), reused 52 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 5.11 MiB | 9.77 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
cd /content/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features/Experiments-Wind/
# Out:
# /content/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features/Experiments-Wind

# %%
ls -l
# Out:
# total 12
# -rw-r--r-- 1 root root 1710 Nov  4 16:19 processing.py
# -rw-r--r-- 1 root root 5043 Nov  4 16:19 RandomFourierFeatures.py

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

import tensorflow as tf
from tensorflow import keras

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score

from processing import create_features, split_data
from RandomFourierFeatures import Conv1dRFF

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #**Parameters**

# %%
window_size = 5
output_dim  = 1000
epochs      = 100
kernel_size = 1

# %% [markdown]
# #**Dataset-1 (May Dataset)**

# %%
df = pd.read_csv('/content/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features/Data/DS2_1448.csv')

# %%
df
# Out:
#                      date  wind_speed
# 0     2015-05-01 00:00:00    7.267950
# 1     2015-05-01 00:30:00    7.741650
# 2     2015-05-01 01:00:00    8.322700
# 3     2015-05-01 01:30:00    8.091600
# 4     2015-05-01 02:00:00    9.346300
# ...                   ...         ...
# 1483  2015-05-31 21:30:00    4.859500
# 1484  2015-05-31 22:00:00    4.628200
# 1485  2015-05-31 22:30:00    4.301300
# 1486  2015-05-31 23:00:00    4.589250
# 1487  2015-05-31 23:30:00    3.255625
#
# [1488 rows x 2 columns]

# %%
train_len = int(.6*df.shape[0])
train_data, val_data, test_data = split_data(df.wind_speed.values, train_len)
train_data = np.float32(train_data)
val_data = np.float32(val_data)
test_data = np.float32(test_data)

train_data.shape, val_data.shape, test_data.shape
# Out:
# ((892,), (298,), (298,))

# %%
plt.figure(figsize=(25, 6))
plt.plot(train_data, color='blue', label='Train Data')
plt.plot(range(len(train_data), len(train_data) + len(val_data)), val_data, color='orange', label='Validation Data')
plt.plot(range(len(train_data) + len(val_data), len(train_data) + len(val_data) + len(test_data)), test_data, color='green', label='Test Data')

plt.xlabel("Index", size=22)
plt.ylabel("Wind Speed", size=22)
plt.xlim(0, len(train_data) + len(val_data) + len(test_data))

# Ajustar el tamaño de los valores de los ejes x e y
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Leyenda en la parte superior, centrada y en 3 columnas
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.02), ncol=3, prop={'size': 22})

plt.show()

# %%
X_train, y_train = create_features(train_data, window_size)
X_valid, y_valid = create_features(val_data, window_size)
X_test, y_test   = create_features(test_data, window_size)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape, X_test.shape, y_test.shape
# Out:
# ((887, 5), (887,), (293, 5), (293,), (293, 5), (293,))

# %% [markdown]
# #**Forecasting**

# %%
input = tf.keras.layers.Input(shape=(X_train.shape[1],1), name='Input')

tmp = Conv1dRFF(output_dim, kernel_size=kernel_size, trainable_W=True, trainable_scale=True)(input)
tmp = tf.keras.layers.Flatten()(tmp)
tmp = tf.keras.layers.Dense(units=32, activation='relu',name='Dense_1')(tmp)
output = tf.keras.layers.Dense(units=1, activation='relu')(tmp)

model = tf.keras.Model(inputs=input, outputs=output)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 5, 1)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_rff_1 (Conv1dRFF)             │ (None, 5, 1000)             │           2,001 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 5000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Dense_1 (Dense)                      │ (None, 32)                  │         160,032 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 162,066 (633.07 KB)
#  Trainable params: 162,066 (633.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=epochs, batch_size=256, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 528ms/step - loss: 35.5339 - mae: 5.5345 - mse: 35.5339 - val_loss: 29.5364 - val_mae: 5.1484 - val_mse: 29.5364
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.4059 - mae: 4.9649 - mse: 29.4059 - val_loss: 22.8054 - val_mae: 4.4780 - val_mse: 22.8054
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.5885 - mae: 4.3576 - mse: 23.5885 - val_loss: 16.2802 - val_mae: 3.7313 - val_mse: 16.2802
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.9199 - mae: 3.5807 - mse: 16.9199 - val_loss: 10.5613 - val_mae: 2.9429 - val_mse: 10.5613
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.2871 - mae: 2.9016 - mse: 12.2871 - val_loss: 6.1076 - val_mae: 2.1818 - val_mse: 6.1076
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.2201 - mae: 2.2218 - mse: 8.2201 - val_loss: 3.2037 - val_mae: 1.5270 - val_mse: 3.2037
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.8260 - mae: 1.7157 - mse: 5.8260 - val_loss: 1.8253 - val_mae: 1.1041 - val_mse: 1.8253
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7116 - mae: 1.3089 - mse: 3.7116 - val_loss: 1.4291 - val_mae: 0.9499 - val_mse: 1.4291
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3483 - mae: 1.2631 - mse: 3.3483 - val_loss: 1.3855 - val_mae: 0.9379 - val_mse: 1.3855
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.9899 - mae: 1.2220 - mse: 2.9899 - val_loss: 1.2888 - val_mae: 0.9063 - val_mse: 1.2888
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9540 - mae: 1.2243 - mse: 2.9540 - val_loss: 1.1381 - val_mae: 0.8520 - val_mse: 1.1381
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4897 - mae: 1.1431 - mse: 2.4897 - val_loss: 1.0558 - val_mae: 0.8241 - val_mse: 1.0558
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0873 - mae: 1.0566 - mse: 2.0873 - val_loss: 1.0536 - val_mae: 0.8303 - val_mse: 1.0536
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6925 - mae: 0.9664 - mse: 1.6925 - val_loss: 1.0358 - val_mae: 0.8239 - val_mse: 1.0358
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7088 - mae: 0.9640 - mse: 1.7088 - val_loss: 0.9885 - val_mae: 0.7968 - val_mse: 0.9885
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4890 - mae: 0.9066 - mse: 1.4890 - val_loss: 0.9355 - val_mae: 0.7626 - val_mse: 0.9355
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5403 - mae: 0.9263 - mse: 1.5403 - val_loss: 0.8997 - val_mae: 0.7380 - val_mse: 0.8997
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3754 - mae: 0.8810 - mse: 1.3754 - val_loss: 0.8737 - val_mae: 0.7234 - val_mse: 0.8737
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3293 - mae: 0.8617 - mse: 1.3293 - val_loss: 0.8513 - val_mae: 0.7151 - val_mse: 0.8513
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3015 - mae: 0.8489 - mse: 1.3015 - val_loss: 0.8369 - val_mae: 0.7114 - val_mse: 0.8369
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2153 - mae: 0.8205 - mse: 1.2153 - val_loss: 0.8316 - val_mae: 0.7097 - val_mse: 0.8316
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2014 - mae: 0.8147 - mse: 1.2014 - val_loss: 0.8297 - val_mae: 0.7108 - val_mse: 0.8297
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2531 - mae: 0.8245 - mse: 1.2531 - val_loss: 0.8197 - val_mae: 0.7036 - val_mse: 0.8197
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.1964 - mae: 0.8230 - mse: 1.1964 - val_loss: 0.8081 - val_mae: 0.6961 - val_mse: 0.8081
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9326 - mae: 0.7129 - mse: 0.9326 - val_loss: 0.7276 - val_mae: 0.6583 - val_mse: 0.7276
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9048 - mae: 0.7112 - mse: 0.9048 - val_loss: 0.7199 - val_mae: 0.6546 - val_mse: 0.7199
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9017 - mae: 0.7091 - mse: 0.9017 - val_loss: 0.7208 - val_mae: 0.6550 - val_mse: 0.7208
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8785 - mae: 0.6996 - mse: 0.8785 - val_loss: 0.7276 - val_mae: 0.6592 - val_mse: 0.7276
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9624 - mae: 0.7323 - mse: 0.9624 - val_loss: 0.7339 - val_mae: 0.6610 - val_mse: 0.7339
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8990 - mae: 0.6999 - mse: 0.8990 - val_loss: 0.7314 - val_mae: 0.6623 - val_mse: 0.7314
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8595 - mae: 0.6952 - mse: 0.8595 - val_loss: 0.7321 - val_mae: 0.6616 - val_mse: 0.7321
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8587 - mae: 0.7005 - mse: 0.8587 - val_loss: 0.7361 - val_mae: 0.6615 - val_mse: 0.7361
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8209 - mae: 0.6827 - mse: 0.8209 - val_loss: 0.7346 - val_mae: 0.6613 - val_mse: 0.7346
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8843 - mae: 0.7019 - mse: 0.8843 - val_loss: 0.7361 - val_mae: 0.6617 - val_mse: 0.7361
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8705 - mae: 0.6918 - mse: 0.8705 - val_loss: 0.7361 - val_mae: 0.6609 - val_mse: 0.7361
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8623 - mae: 0.6953 - mse: 0.8623 - val_loss: 0.7354 - val_mae: 0.6593 - val_mse: 0.7354
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8873 - mae: 0.7068 - mse: 0.8873 - val_loss: 0.7318 - val_mae: 0.6572 - val_mse: 0.7318
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8612 - mae: 0.6917 - mse: 0.8612 - val_loss: 0.7405 - val_mae: 0.6599 - val_mse: 0.7405
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8737 - mae: 0.6991 - mse: 0.8737 - val_loss: 0.7405 - val_mae: 0.6621 - val_mse: 0.7405
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8993 - mae: 0.7094 - mse: 0.8993 - val_loss: 0.7454 - val_mae: 0.6649 - val_mse: 0.7454
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8825 - mae: 0.6930 - mse: 0.8825 - val_loss: 0.7460 - val_mae: 0.6635 - val_mse: 0.7460
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.8581 - mae: 0.6955 - mse: 0.8581 - val_loss: 0.7499 - val_mae: 0.6642 - val_mse: 0.7499
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8358 - mae: 0.6875 - mse: 0.8358 - val_loss: 0.7451 - val_mae: 0.6632 - val_mse: 0.7451
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8717 - mae: 0.6944 - mse: 0.8717 - val_loss: 0.7476 - val_mae: 0.6669 - val_mse: 0.7476

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.grid(True)
plt.show()

# %%
forecasting = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step

# %%
plt.figure(figsize=(25, 6))
plt.plot(y_test, color='blue', label='Actual')
plt.plot(forecasting, color='orange', label='Predicted')

plt.xlabel("Index", size=20)
plt.ylabel("Value", size=20)

# Ajustar el tamaño de los valores de los ejes x e y
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Leyenda en la parte superior, centrada y en 3 columnas
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.02), ncol=3, prop={'size': 20})

plt.show()

# %%
R2 = round(r2_score(y_test, np.squeeze(forecasting)), 3)
RMSE = round(mean_squared_error(y_test, np.squeeze(forecasting), squared=False), 3)
MAE = round(mean_absolute_error(y_test, np.squeeze(forecasting)), 3)
MAPE = round(np.mean(np.abs((y_test - np.squeeze(forecasting)) / y_test)) * 100, 3)

# Muestra los resultados
print(f"R2: {R2}")
print(f"RMSE: {RMSE}")
print(f"MAE: {MAE}")
print(f"MAPE: {MAPE}%")
# Out:
# R2: 0.689
# RMSE: 1.1059999465942383
# MAE: 0.8510000109672546
# MAPE: 16.425%
