# %%
# !pip install tensorflow==2.14.0 tensorflow-gpu
# !pip install tabulate
# Out:
# Collecting tensorflow==2.14.0
#   Downloading tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)

# %%
# !git clone https://github.com/ealeongomez/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features.git
# Out:
# Cloning into 'Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 97 (delta 9), reused 13 (delta 6), pack-reused 81 (from 1)
# Receiving objects: 100% (97/97), 151.77 MiB | 13.48 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Updating files: 100% (32/32), done.

# %%
cd /content/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features/Experiments-Wind/
# Out:
# /content/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features/Experiments-Wind

# %%
ls -l
# Out:
# total 948
# -rw-r--r-- 1 root root   1710 Nov  4 23:08 processing.py
# -rw-r--r-- 1 root root   5782 Nov  4 23:08 RandomFourierFeatures.py
# -rw-r--r-- 1 root root 456247 Nov  4 23:08 RFF-DataSet-1.ipynb
# -rw-r--r-- 1 root root 498840 Nov  4 23:08 RFF-DataSet-2.ipynb

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from tabulate import tabulate

import tensorflow as tf
from tensorflow import keras

from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score

from processing import create_features, split_data
from RandomFourierFeatures import Conv1dRFF

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #**Parameters**

# %%
window_size = 5
output_dim  = 1000
epochs      = 100
kernel_size = 1

# %% [markdown]
# #**Dataset-1 (May Dataset)**

# %%
df = pd.read_csv('/content/Time-Series-Forecasting-Using-the-Bayesian-Approach-and-Random-Fourier-Features/Data/DS2_1448.csv')

# %%
df
# Out:
#                      date  wind_speed
# 0     2015-05-01 00:00:00    7.267950
# 1     2015-05-01 00:30:00    7.741650
# 2     2015-05-01 01:00:00    8.322700
# 3     2015-05-01 01:30:00    8.091600
# 4     2015-05-01 02:00:00    9.346300
# ...                   ...         ...
# 1483  2015-05-31 21:30:00    4.859500
# 1484  2015-05-31 22:00:00    4.628200
# 1485  2015-05-31 22:30:00    4.301300
# 1486  2015-05-31 23:00:00    4.589250
# 1487  2015-05-31 23:30:00    3.255625
#
# [1488 rows x 2 columns]

# %%
train_len = int(.6*df.shape[0])
train_data, val_data, test_data = split_data(df.wind_speed.values, train_len)
train_data = np.float32(train_data)
val_data = np.float32(val_data)
test_data = np.float32(test_data)

train_data.shape, val_data.shape, test_data.shape
# Out:
# ((892,), (298,), (298,))

# %%
plt.figure(figsize=(25, 6))
plt.plot(train_data, color='blue', label='Train Data')
plt.plot(range(len(train_data), len(train_data) + len(val_data)), val_data, color='orange', label='Validation Data')
plt.plot(range(len(train_data) + len(val_data), len(train_data) + len(val_data) + len(test_data)), test_data, color='green', label='Test Data')

plt.xlabel("Index", size=22)
plt.ylabel("Wind Speed", size=22)
plt.xlim(0, len(train_data) + len(val_data) + len(test_data))

# Ajustar el tamaño de los valores de los ejes x e y
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Leyenda en la parte superior, centrada y en 3 columnas
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.02), ncol=3, prop={'size': 22})

plt.show()

# %%
X_train, y_train = create_features(train_data, window_size)
X_valid, y_valid = create_features(val_data, window_size)
X_test, y_test   = create_features(test_data, window_size)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape, X_test.shape, y_test.shape
# Out:
# ((887, 5), (887,), (293, 5), (293,), (293, 5), (293,))

# %% [markdown]
# #**Forecasting**

# %%
input = tf.keras.layers.Input(shape=(X_train.shape[1],1), name='Input')

tmp = Conv1dRFF(output_dim, kernel_size=kernel_size, trainable_W=True, trainable_scale=True)(input)
tmp = tf.keras.layers.Flatten()(tmp)
tmp = tf.keras.layers.Dense(units=32, activation='relu',name='Dense_1')(tmp)
output = tf.keras.layers.Dense(units=1, activation='relu')(tmp)

model = tf.keras.Model(inputs=input, outputs=output)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 5, 1)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_rff (Conv1dRFF)               │ (None, 5, 1000)             │           2,001 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 5000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Dense_1 (Dense)                      │ (None, 32)                  │         160,032 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 162,066 (633.07 KB)
#  Trainable params: 162,066 (633.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=epochs, batch_size=256, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 530ms/step - loss: 37.0915 - mae: 5.6587 - mse: 37.0915 - val_loss: 31.1607 - val_mae: 5.3360 - val_mse: 31.1607
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 33.3876 - mae: 5.3264 - mse: 33.3876 - val_loss: 25.9502 - val_mae: 4.8551 - val_mse: 25.9502
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.6846 - mae: 4.9617 - mse: 29.6846 - val_loss: 20.5681 - val_mae: 4.3071 - val_mse: 20.5681
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 26.4087 - mae: 4.5834 - mse: 26.4087 - val_loss: 15.4259 - val_mae: 3.7088 - val_mse: 15.4259
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.6671 - mae: 4.1341 - mse: 22.6671 - val_loss: 10.9101 - val_mae: 3.0822 - val_mse: 10.9101
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 18.2807 - mae: 3.5816 - mse: 18.2807 - val_loss: 7.2313 - val_mae: 2.4576 - val_mse: 7.2313
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.4002 - mae: 3.0150 - mse: 14.4002 - val_loss: 4.5765 - val_mae: 1.8885 - val_mse: 4.5765
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.2610 - mae: 2.4982 - mse: 11.2610 - val_loss: 2.9115 - val_mae: 1.4287 - val_mse: 2.9115
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.0861 - mae: 1.9844 - mse: 8.0861 - val_loss: 2.0694 - val_mae: 1.1267 - val_mse: 2.0694
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.6223 - mae: 1.7161 - mse: 6.6223 - val_loss: 1.7381 - val_mae: 1.0134 - val_mse: 1.7381
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.2642 - mae: 1.5137 - mse: 5.2642 - val_loss: 1.6237 - val_mae: 0.9933 - val_mse: 1.6237
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8072 - mae: 1.4301 - mse: 4.8072 - val_loss: 1.5393 - val_mae: 0.9728 - val_mse: 1.5393
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0919 - mae: 1.3591 - mse: 4.0919 - val_loss: 1.4221 - val_mae: 0.9377 - val_mse: 1.4221
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.9324 - mae: 1.3228 - mse: 3.9324 - val_loss: 1.3071 - val_mae: 0.9058 - val_mse: 1.3071
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.2580 - mae: 1.2160 - mse: 3.2580 - val_loss: 1.2359 - val_mae: 0.8901 - val_mse: 1.2359
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9367 - mae: 1.1581 - mse: 2.9367 - val_loss: 1.2091 - val_mae: 0.8929 - val_mse: 1.2091
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7043 - mae: 1.1056 - mse: 2.7043 - val_loss: 1.1903 - val_mae: 0.8925 - val_mse: 1.1903
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2883 - mae: 1.0626 - mse: 2.2883 - val_loss: 1.1368 - val_mae: 0.8728 - val_mse: 1.1368
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2381 - mae: 1.0485 - mse: 2.2381 - val_loss: 1.0644 - val_mae: 0.8410 - val_mse: 1.0644
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0476 - mae: 1.0310 - mse: 2.0476 - val_loss: 0.9882 - val_mae: 0.8026 - val_mse: 0.9882
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8862 - mae: 0.9933 - mse: 1.8862 - val_loss: 0.9315 - val_mae: 0.7697 - val_mse: 0.9315
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6595 - mae: 0.9465 - mse: 1.6595 - val_loss: 0.8981 - val_mae: 0.7484 - val_mse: 0.8981
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6000 - mae: 0.9403 - mse: 1.6000 - val_loss: 0.8791 - val_mae: 0.7344 - val_mse: 0.8791
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5993 - mae: 0.9373 - mse: 1.5993 - val_loss: 0.8632 - val_mae: 0.7249 - val_mse: 0.8632
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5329 - mae: 0.9166 - mse: 1.5329 - val_loss: 0.8494 - val_mae: 0.7191 - val_mse: 0.8494
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.3728 - mae: 0.8875 - mse: 1.3728 - val_loss: 0.8400 - val_mae: 0.7161 - val_mse: 0.8400
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3720 - mae: 0.8689 - mse: 1.3720 - val_loss: 0.8334 - val_mae: 0.7141 - val_mse: 0.8334
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.4193 - mae: 0.8810 - mse: 1.4193 - val_loss: 0.8292 - val_mae: 0.7134 - val_mse: 0.8292
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3488 - mae: 0.8585 - mse: 1.3488 - val_loss: 0.8244 - val_mae: 0.7112 - val_mse: 0.8244
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3295 - mae: 0.8616 - mse: 1.3295 - val_loss: 0.8192 - val_mae: 0.7085 - val_mse: 0.8192
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2408 - mae: 0.8350 - mse: 1.2408 - val_loss: 0.8130 - val_mae: 0.7033 - val_mse: 0.8130
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2876 - mae: 0.8440 - mse: 1.2876 - val_loss: 0.8083 - val_mae: 0.7000 - val_mse: 0.8083
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2131 - mae: 0.8211 - mse: 1.2131 - val_loss: 0.8030 - val_mae: 0.6961 - val_mse: 0.8030
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1782 - mae: 0.8095 - mse: 1.1782 - val_loss: 0.7972 - val_mae: 0.6932 - val_mse: 0.7972
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2509 - mae: 0.8192 - mse: 1.2509 - val_loss: 0.7909 - val_mae: 0.6901 - val_mse: 0.7909
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2199 - mae: 0.8202 - mse: 1.2199 - val_loss: 0.7863 - val_mae: 0.6889 - val_mse: 0.7863
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1746 - mae: 0.8013 - mse: 1.1746 - val_loss: 0.7806 - val_mae: 0.6881 - val_mse: 0.7806
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1742 - mae: 0.8160 - mse: 1.1742 - val_loss: 0.7760 - val_mae: 0.6866 - val_mse: 0.7760
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1740 - mae: 0.8003 - mse: 1.1740 - val_loss: 0.7719 - val_mae: 0.6834 - val_mse: 0.7719
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1224 - mae: 0.7855 - mse: 1.1224 - val_loss: 0.7680 - val_mae: 0.6810 - val_mse: 0.7680
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0789 - mae: 0.7610 - mse: 1.0789 - val_loss: 0.7637 - val_mae: 0.6784 - val_mse: 0.7637
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1230 - mae: 0.7869 - mse: 1.1230 - val_loss: 0.7582 - val_mae: 0.6756 - val_mse: 0.7582
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1506 - mae: 0.7816 - mse: 1.1506 - val_loss: 0.7551 - val_mae: 0.6739 - val_mse: 0.7551
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.1073 - mae: 0.7693 - mse: 1.1073 - val_loss: 0.7529 - val_mae: 0.6729 - val_mse: 0.7529
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1051 - mae: 0.7771 - mse: 1.1051 - val_loss: 0.7484 - val_mae: 0.6721 - val_mse: 0.7484
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0665 - mae: 0.7644 - mse: 1.0665 - val_loss: 0.7452 - val_mae: 0.6718 - val_mse: 0.7452
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0706 - mae: 0.7743 - mse: 1.0706 - val_loss: 0.7425 - val_mae: 0.6701 - val_mse: 0.7425
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0354 - mae: 0.7598 - mse: 1.0354 - val_loss: 0.7402 - val_mae: 0.6680 - val_mse: 0.7402
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0611 - mae: 0.7642 - mse: 1.0611 - val_loss: 0.7383 - val_mae: 0.6663 - val_mse: 0.7383
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0668 - mae: 0.7612 - mse: 1.0668 - val_loss: 0.7349 - val_mae: 0.6638 - val_mse: 0.7349
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0751 - mae: 0.7719 - mse: 1.0751 - val_loss: 0.7311 - val_mae: 0.6631 - val_mse: 0.7311
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1113 - mae: 0.7759 - mse: 1.1113 - val_loss: 0.7322 - val_mae: 0.6657 - val_mse: 0.7322
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0363 - mae: 0.7566 - mse: 1.0363 - val_loss: 0.7323 - val_mae: 0.6666 - val_mse: 0.7323
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1196 - mae: 0.7842 - mse: 1.1196 - val_loss: 0.7343 - val_mae: 0.6671 - val_mse: 0.7343
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0550 - mae: 0.7579 - mse: 1.0550 - val_loss: 0.7342 - val_mae: 0.6629 - val_mse: 0.7342
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0979 - mae: 0.7771 - mse: 1.0979 - val_loss: 0.7347 - val_mae: 0.6633 - val_mse: 0.7347
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0432 - mae: 0.7570 - mse: 1.0432 - val_loss: 0.7322 - val_mae: 0.6626 - val_mse: 0.7322
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0362 - mae: 0.7575 - mse: 1.0362 - val_loss: 0.7303 - val_mae: 0.6640 - val_mse: 0.7303
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0820 - mae: 0.7730 - mse: 1.0820 - val_loss: 0.7281 - val_mae: 0.6619 - val_mse: 0.7281
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0216 - mae: 0.7509 - mse: 1.0216 - val_loss: 0.7281 - val_mae: 0.6610 - val_mse: 0.7281
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0099 - mae: 0.7466 - mse: 1.0099 - val_loss: 0.7288 - val_mae: 0.6617 - val_mse: 0.7288
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0060 - mae: 0.7484 - mse: 1.0060 - val_loss: 0.7274 - val_mae: 0.6608 - val_mse: 0.7274
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9678 - mae: 0.7382 - mse: 0.9678 - val_loss: 0.7250 - val_mae: 0.6600 - val_mse: 0.7250
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0285 - mae: 0.7536 - mse: 1.0285 - val_loss: 0.7258 - val_mae: 0.6620 - val_mse: 0.7258
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9739 - mae: 0.7315 - mse: 0.9739 - val_loss: 0.7245 - val_mae: 0.6622 - val_mse: 0.7245
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0741 - mae: 0.7690 - mse: 1.0741 - val_loss: 0.7260 - val_mae: 0.6611 - val_mse: 0.7260
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0100 - mae: 0.7439 - mse: 1.0100 - val_loss: 0.7260 - val_mae: 0.6592 - val_mse: 0.7260
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0247 - mae: 0.7486 - mse: 1.0247 - val_loss: 0.7251 - val_mae: 0.6588 - val_mse: 0.7251
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9933 - mae: 0.7437 - mse: 0.9933 - val_loss: 0.7259 - val_mae: 0.6606 - val_mse: 0.7259
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9866 - mae: 0.7365 - mse: 0.9866 - val_loss: 0.7254 - val_mae: 0.6620 - val_mse: 0.7254
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0094 - mae: 0.7437 - mse: 1.0094 - val_loss: 0.7251 - val_mae: 0.6635 - val_mse: 0.7251
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9526 - mae: 0.7318 - mse: 0.9526 - val_loss: 0.7232 - val_mae: 0.6626 - val_mse: 0.7232
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9673 - mae: 0.7476 - mse: 0.9673 - val_loss: 0.7206 - val_mae: 0.6588 - val_mse: 0.7206
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0039 - mae: 0.7412 - mse: 1.0039 - val_loss: 0.7187 - val_mae: 0.6575 - val_mse: 0.7187
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0169 - mae: 0.7433 - mse: 1.0169 - val_loss: 0.7203 - val_mae: 0.6589 - val_mse: 0.7203
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9652 - mae: 0.7395 - mse: 0.9652 - val_loss: 0.7221 - val_mae: 0.6617 - val_mse: 0.7221
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0013 - mae: 0.7422 - mse: 1.0013 - val_loss: 0.7290 - val_mae: 0.6666 - val_mse: 0.7290
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9698 - mae: 0.7299 - mse: 0.9698 - val_loss: 0.7265 - val_mae: 0.6635 - val_mse: 0.7265
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0285 - mae: 0.7466 - mse: 1.0285 - val_loss: 0.7250 - val_mae: 0.6606 - val_mse: 0.7250
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9661 - mae: 0.7362 - mse: 0.9661 - val_loss: 0.7228 - val_mae: 0.6573 - val_mse: 0.7228
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0510 - mae: 0.7590 - mse: 1.0510 - val_loss: 0.7214 - val_mae: 0.6561 - val_mse: 0.7214
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9624 - mae: 0.7235 - mse: 0.9624 - val_loss: 0.7193 - val_mae: 0.6560 - val_mse: 0.7193
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8924 - mae: 0.7054 - mse: 0.8924 - val_loss: 0.7176 - val_mae: 0.6581 - val_mse: 0.7176
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9707 - mae: 0.7317 - mse: 0.9707 - val_loss: 0.7150 - val_mae: 0.6586 - val_mse: 0.7150
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9142 - mae: 0.7219 - mse: 0.9142 - val_loss: 0.7126 - val_mae: 0.6545 - val_mse: 0.7126
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9751 - mae: 0.7337 - mse: 0.9751 - val_loss: 0.7136 - val_mae: 0.6540 - val_mse: 0.7136
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9798 - mae: 0.7370 - mse: 0.9798 - val_loss: 0.7158 - val_mae: 0.6553 - val_mse: 0.7158
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0120 - mae: 0.7386 - mse: 1.0120 - val_loss: 0.7166 - val_mae: 0.6529 - val_mse: 0.7166
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9721 - mae: 0.7380 - mse: 0.9721 - val_loss: 0.7140 - val_mae: 0.6531 - val_mse: 0.7140
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9137 - mae: 0.7138 - mse: 0.9137 - val_loss: 0.7188 - val_mae: 0.6597 - val_mse: 0.7188
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9683 - mae: 0.7343 - mse: 0.9683 - val_loss: 0.7205 - val_mae: 0.6607 - val_mse: 0.7205
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0433 - mae: 0.7512 - mse: 1.0433 - val_loss: 0.7203 - val_mae: 0.6582 - val_mse: 0.7203
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0088 - mae: 0.7410 - mse: 1.0088 - val_loss: 0.7195 - val_mae: 0.6574 - val_mse: 0.7195
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9183 - mae: 0.7217 - mse: 0.9183 - val_loss: 0.7177 - val_mae: 0.6573 - val_mse: 0.7177
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9302 - mae: 0.7167 - mse: 0.9302 - val_loss: 0.7204 - val_mae: 0.6593 - val_mse: 0.7204
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9556 - mae: 0.7230 - mse: 0.9556 - val_loss: 0.7213 - val_mae: 0.6601 - val_mse: 0.7213
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9538 - mae: 0.7237 - mse: 0.9538 - val_loss: 0.7213 - val_mae: 0.6611 - val_mse: 0.7213
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9308 - mae: 0.7179 - mse: 0.9308 - val_loss: 0.7219 - val_mae: 0.6615 - val_mse: 0.7219
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9449 - mae: 0.7213 - mse: 0.9449 - val_loss: 0.7230 - val_mae: 0.6634 - val_mse: 0.7230
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9119 - mae: 0.7122 - mse: 0.9119 - val_loss: 0.7246 - val_mae: 0.6646 - val_mse: 0.7246

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.grid(True)
plt.show()

# %%
forecasting = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step

# %%
plt.figure(figsize=(25, 6))
plt.plot(y_test, color='blue', label='Actual')
plt.plot(forecasting, color='orange', label='Predicted')

plt.xlabel("Index", size=20)
plt.ylabel("Value", size=20)

# Ajustar el tamaño de los valores de los ejes x e y
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Leyenda en la parte superior, centrada y en 3 columnas
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.02), ncol=3, prop={'size': 20})

plt.show()

# %%
R2 = round(r2_score(y_test, np.squeeze(forecasting)), 3)
RMSE = round(mean_squared_error(y_test, np.squeeze(forecasting), squared=False), 3)
MAE = round(mean_absolute_error(y_test, np.squeeze(forecasting)), 3)
MAPE = round(np.mean(np.abs((y_test - np.squeeze(forecasting)) / y_test)) * 100, 3)

# %%
table = [["RMSE",RMSE],["MAE",MAE], ["MAPE (%)",MAPE],["R2",R2]]

print(tabulate(table))
# Out:
# --------  ------
# RMSE       1.091
# MAE        0.846
# MAPE (%)  16.378
# R2         0.697
# --------  ------
